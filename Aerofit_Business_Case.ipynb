# %% [markdown]
# <a href="https://colab.research.google.com/github/KarivetiKeerthi/Scaler-Projects/blob/main/Aerofit_Business_Case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install numpy

# %%
df=pd.read_csv("https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/aerofit_treadmill.csv")
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include='object').T
# Out:
#               count unique        top freq
# Product         180      3      KP281   80
# Gender          180      2       Male  104
# MaritalStatus   180      2  Partnered  107

# %%
df.shape
# Out:
# (180, 9)

# %%
df.isnull().sum()/len(df)*100
# Out:
# Product          0.0
# Age              0.0
# Gender           0.0
# Education        0.0
# MaritalStatus    0.0
# Usage            0.0
# Fitness          0.0
# Income           0.0
# Miles            0.0
# dtype: float64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
unique = df.nunique()
unique
# Out:
# Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %%
df['Product'].value_counts(normalize=True)*100
# Out:
# KP281    44.444444
# KP481    33.333333
# KP781    22.222222
# Name: Product, dtype: float64

# %%
df['Gender'].value_counts(normalize=True)*100
# Out:
# Male      57.777778
# Female    42.222222
# Name: Gender, dtype: float64

# %%
df['MaritalStatus'].value_counts(normalize=True)*100
# Out:
# Partnered    59.444444
# Single       40.555556
# Name: MaritalStatus, dtype: float64

# %%
df['Gender'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Gender'>

# %%
df['Product'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Product'>

# %%
df['MaritalStatus'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='MaritalStatus'>

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   KP781   40   Male         21        Single      6        5   83416
# 176   KP781   42   Male         18        Single      5        4   89641
# 177   KP781   45   Male         16        Single      5        5   90886
# 178   KP781   47   Male         18     Partnered      4        5  104581
# 179   KP781   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
plt.figure(figsize=(7,5))
sns.distplot(df['Age'],kde=False, color='darkblue', bins=30)
# Out:
# <ipython-input-19-4c8a96150a99>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],kde=False, color='darkblue', bins=30)
# <Axes: xlabel='Age'>

# %%
plt.figure(figsize=(7,5))
sns.distplot(df['Income'],kde=False, color='red', bins=50)
# Out:
# <ipython-input-9-0aea272a638b>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Income'],kde=False, color='red', bins=50)
# <Axes: xlabel='Income'>

# %%
sns.countplot(x='Product', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
sns.countplot(x='Product', hue='MaritalStatus', data=df)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='Age', hue='Product', width=1, data=df)
plt.title('Product-Age Count Plot')
# Out:
# Text(0.5, 1.0, 'Product-Age Count Plot')

# %%
sns.countplot(x='Education', hue='Product', width=1, data=df)
plt.title('Product-Education Count Plot', size= 10)
# Out:
# Text(0.5, 1.0, 'Product-Education Count Plot')

# %%
sns.histplot(data = df,x ='Age',hue = 'Product',element = 'poly')
plt.title('Age-Product HistPlot', size= 10)
# Out:
# Text(0.5, 1.0, 'Age-Product HistPlot')

# %%
sns.histplot(data = df,x='Usage',y='Age',hue = 'Product')
plt.title('Age-Usage HistPlot', size= 10)
# Out:
# Text(0.5, 1.0, 'Age-Usage HistPlot')

# %%
sns.histplot(data = df,x ='Product',y = 'Income',hue = 'Gender',element = 'poly')
plt.title('Income-Product HistPlot', size= 10)
# Out:
# Text(0.5, 1.0, 'Income-Product HistPlot')

# %%
sns.histplot(data = df,x ='Age',y = 'Miles',hue = 'Product')
plt.title('Age-Miles HistPlot', size= 10)
# Out:
# Text(0.5, 1.0, 'Age-Miles HistPlot')

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x = 'Usage', y = 'Age', hue='Product')
plt.title('Age-Usage BoxPlot', size= 12)
# Out:
# Text(0.5, 1.0, 'Age-Usage BoxPlot')

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=df, x = 'Age', y = 'Income', hue='Product')
plt.title('Age-Income BoxPlot', size= 12);

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x = 'Gender', y = 'Miles', hue='MaritalStatus')
plt.title('Gender-Miles BoxPlot', size= 12)
# Out:
# Text(0.5, 1.0, 'Gender-Miles BoxPlot')

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x = 'Fitness', y = 'Income', hue='Product')
plt.title('Fitness-Income BoxPlot', size= 12)
# Out:
# Text(0.5, 1.0, 'Fitness-Income BoxPlot')

# %%
sns.pairplot(data=df,hue='Product')

# %%
sns.pairplot(data=df,hue='Gender')

# %%
sns.pairplot(data=df,hue='MaritalStatus')

# %%
sns.heatmap(df, cmap='coolwarm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-04d1db9e1cdf> in <cell line: 1>()
# ----> 1 sns.heatmap(df, cmap='coolwarm')
#       2 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     444     """
#     445     # Initialize the plotter object
# --> 446     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                           annot_kws, cbar, cbar_kws, xticklabels,
#     448                           yticklabels, mask)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     161
# ...

# %%
df.isna()
# Out:
#      Product    Age  Gender  Education  MaritalStatus  Usage  Fitness  Income  \
# 0      False  False   False      False          False  False    False   False
# 1      False  False   False      False          False  False    False   False
# 2      False  False   False      False          False  False    False   False
# 3      False  False   False      False          False  False    False   False
# 4      False  False   False      False          False  False    False   False
# ..       ...    ...     ...        ...            ...    ...      ...     ...
# 175    False  False   False      False          False  False    False   False
# 176    False  False   False      False          False  False    False   False
# 177    False  False   False      False          False  False    False   False
# 178    False  False   False      False          False  False    False   False
# 179    False  False   False      False          False  False    False   False
#
#      Miles
# 0    False
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Product, Age, Gender, Education, MaritalStatus, Usage, Fitness, Income, Miles]
# Index: []

# %%
  df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
Q1 = np.percentile(df['Miles'], 25, method='midpoint')
Q3 = np.percentile(df['Miles'], 75, method='midpoint')
IQR_M = Q3 - Q1
print(IQR_M)
# Out:
# 50.5

# %%
Q1 = np.percentile(df['Education'], 25, method='midpoint')
Q3 = np.percentile(df['Education'], 75, method='midpoint')
IQR_E = Q3 - Q1
print(IQR_E)
# Out:
# 2.0

# %%
Q1 = np.percentile(df['Usage'], 25, method='midpoint')
Q3 = np.percentile(df['Usage'], 75, method='midpoint')
IQR_U = Q3 - Q1
print(IQR_U)
# Out:
# 1.0

# %%
Q1 = np.percentile(df['Income'], 25, method='midpoint')
Q3 = np.percentile(df['Income'], 75, method='midpoint')
IQR_I = Q3 - Q1
print(IQR_I)
# Out:
# 15045.5

# %%
pd.crosstab(index=df['Product'], columns=df['Gender'], values=df['Income'], aggfunc='sum', margins=True, normalize='index')
# Out:
# Gender     Female      Male
# Product
# KP281    0.495713  0.504287
# KP481    0.486914  0.513086
# KP781    0.170807  0.829193
# All      0.391643  0.608357

# %%
pd.crosstab(index=df['Product'], columns=df['Age'], values=df['Usage'], aggfunc='sum', margins=True, normalize='index')
# Out:
# Age            18        19        20        21        22        23        24  \
# Product
# KP281    0.012146  0.036437  0.028340  0.052632  0.052632  0.105263  0.072874
# KP481    0.000000  0.016304  0.043478  0.048913  0.000000  0.119565  0.048913
# KP781    0.000000  0.000000  0.000000  0.000000  0.057592  0.068063  0.094241
# All      0.004823  0.019293  0.024116  0.035370  0.038585  0.098071  0.072347
#
# Age            25        26        27  ...        40        41        42  \
# Product                                ...
# KP281    0.072874  0.089069  0.036437  ...  0.012146  0.016194  0.000000
# KP481    0.173913  0.065217  0.021739  ...  0.048913  0.000000  0.000000
# KP781    0.172775  0.047120  0.062827  ...  0.031414  0.000000  0.026178
# All      0.133441  0.069132  0.040193  ...  0.028939  0.006431  0.008039
#
# Age            43        44        45        46        47        48        50
# Product
# ...

# %%
pd.crosstab(index=df['Product'], columns=df['Usage'], values=df['Miles'], aggfunc='sum',normalize='index')
# Out:
# Usage           2         3         4         5         6         7
# Product
# KP281    0.171674  0.444814  0.333837  0.049675  0.000000  0.000000
# KP481    0.150682  0.509856  0.261183  0.078279  0.000000  0.000000
# KP781    0.000000  0.017975  0.388856  0.298083  0.223188  0.071899

# %%
pd.crosstab(index=df['Product'], columns=df['Usage'], values=df['Income'], aggfunc='sum', margins=True, normalize='index')
# Out:
# Usage           2         3         4         5         6         7
# Product
# KP281    0.237600  0.466626  0.274342  0.021433  0.000000  0.000000
# KP481    0.226114  0.516956  0.210884  0.046046  0.000000  0.000000
# KP781    0.000000  0.018153  0.428995  0.302831  0.195974  0.054047

# %%
pd.crosstab(index=df['Product'], columns=df['MaritalStatus'], values=df['Fitness'], aggfunc='sum', margins=True, normalize='index')
# Out:
# MaritalStatus  Partnered    Single
# Product
# KP281           0.578059  0.421941
# KP481           0.603448  0.396552
# KP781           0.583784  0.416216
# All             0.587248  0.412752

# %%
pd.crosstab(index=df['Product'], columns=df['Gender'], values=df['Education'], aggfunc='sum', margins=True, normalize='index')
# Out:
# Gender     Female      Male
# Product
# KP281    0.502078  0.497922
# KP481    0.486218  0.513782
# KP781    0.180375  0.819625
# All      0.417410  0.582590
